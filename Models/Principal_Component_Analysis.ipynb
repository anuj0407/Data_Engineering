# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
import numpy as np

# %%
# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# %%
# Standardize features (important for PCA)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Create and apply PCA
pca = PCA(n_components=2)  # Reduce to 2 dimensions
X_pca = pca.fit_transform(X_scaled)

# %%
# Analyze results
print(f"Original shape: {X.shape}")
print(f"Transformed shape: {X_pca.shape}")
print(f"Explained variance ratio: {pca.explained_variance_ratio_}")
print(f"Cumulative explained variance: {np.cumsum(pca.explained_variance_ratio_)}")
print(f"Principal components:\n{pca.components_}")
# Out:
# Original shape: (150, 4)
# Transformed shape: (150, 2)
# Explained variance ratio: [0.72962445 0.22850762]
# Cumulative explained variance: [0.72962445 0.95813207]
# Principal components:
# [[ 0.52106591 -0.26934744  0.5804131   0.56485654]
#  [ 0.37741762  0.92329566  0.02449161  0.06694199]]

# %%
# Determine optimal number of components
pca_full = PCA()
pca_full.fit(X_scaled)
cumsum = np.cumsum(pca_full.explained_variance_ratio_)
n_components = np.argmax(cumsum >= 0.95) + 1  # 95% variance threshold
print(f"Components needed for 95% variance: {n_components}")
# Out:
# Components needed for 95% variance: 2

# %% [markdown]
# ## Reconstruct data :
# - After regeneration Data might not be simillar as original since ,In dimensonaily reduction some variance get dropped.

# %%
# Inverse transform (reconstruct data)
X_reconstructed = pca.inverse_transform(X_pca)
X_reconstructed = scaler.inverse_transform(X_reconstructed)
